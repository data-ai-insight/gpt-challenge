# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

# OpenAI 모델 설정
chat = ChatOpenAI(
    temperature=0.7,  # 창의적인 응답을 위해 온도 조정
    streaming=True,
    model="gpt-3.5-turbo",
    callbacks=[StreamingStdOutCallbackHandler()],
)

# 시 생성 프롬프트
poem_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a creative poet who writes inspiring poems about programming languages.",
        ),
        (
            "human",
            "Write a poem about the programming language {language}. Highlight its features and philosophy in a poetic way.",
        ),
    ]
)

# 시 생성 체인
poem_chain = poem_prompt | chat

# 설명 프롬프트
explanation_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a programming language expert providing detailed explanations about programming languages.",
        ),
        (
            "human",
            "Explain the programming language {language} in detail. Include its purpose, unique features, use cases, and significance.",
        ),
    ]
)

# 설명 체인
explanation_chain = explanation_prompt | chat

# 최종 체인: 시 생성 결과를 설명 체인으로 연결
final_chain = {"language": poem_chain} | explanation_chain

# %%
# 실행 예시
final_chain.invoke({"language": "Java"})
# Out:
# In the realm of coding, a language divine,
# Java shines bright with a radiant design.
# Elegant and robust, it stands the test of time,
# A versatile tool, a programmer's prime.
#
# With its write once, run anywhere grace,
# Java dances through platforms with effortless pace.
# Object-oriented, its structure sublime,
# Encapsulating data in a seamless rhyme.
#
# From desktops to servers, it spreads its wings,
# Handling tasks big and small, the joy it brings.
# Threads and exceptions, it handles with care,
# Java, a language beyond compare.
#
# In the vast world of tech, a guiding light,
# Java leads the way with power and might.
# A language of order, precision, and grace,
# Forever beloved in the coding space.
#
# So raise a toast to Java, noble and true,
# A language so timeless, a dream come true.
# In the hands of programmers, its magic unfurls,
# Java, the language that rules the coding world.Content="In the realm of coding, a language divine,
# Java shines bright with a radiant design.
# Elegant and robust, it stands the test of time,
# A versatile tool, a programmer's prime.
#
# With its write once, run anywhere grace,
# Java dances through platforms with effortless pace.
# Object-oriented, its structure sublime,
# Encapsulating data in a seamless rhyme.
#
# From desktops to servers, it spreads its wings,
# Handling tasks big and small, the joy it brings.
# Threads and exceptions, it handles with care,
# Java, a language beyond compare.
#
# In the vast world of tech, a guiding light,
# Java leads the way with power and might.
# A language of order, precision, and grace,
# Forever beloved in the coding space.
#
# So raise a toast to Java, noble and true,
# A language so timeless, a dream come true.
# In the hands of programmers, its magic unfurls,
# Java, the language that rules the coding world."
#
# Java is a high-level, object-oriented programming language known for its portability, performance, and reliability. Developed by Sun Microsystems (now owned by Oracle Corporation), Java has become one of the most popular languages in the software development industry. Let's break down the key aspects of Java mentioned in the content:
#
# 1. **Versatile and Robust:** Java is known for its versatility and robustness. It can be used for a wide range of applications, from desktop software to web applications, mobile apps, and enterprise systems.
#
# 2. **Write Once, Run Anywhere (WORA):** Java's WORA principle allows developers to write code once and run it on any platform that supports Java without the need for recompilation. This makes Java highly portable and platform-independent.
#
# 3. **Object-Oriented:** Java is a fully object-oriented language, which means it revolves around the concept of objects and classes. This paradigm promotes code reusability, modularity, and a clear structure.
#
# 4. **Exception Handling:** Java provides robust mechanisms for handling exceptions, which are runtime errors that can occur during program execution. By using try-catch blocks, developers can gracefully handle exceptions and prevent program crashes.
#
# 5. **Multithreading Support:** Java offers built-in support for multithreading, allowing developers to create programs that can execute multiple tasks concurrently. This feature is essential for developing responsive and efficient applications.
#
# 6. **Scalability:** Java is well-suited for building scalable applications, from small utilities to large-scale enterprise systems. Its performance and scalability make it a popular choice for mission-critical applications.
#
# 7. **Community Support:** Java has a large and active community of developers, which provides a wealth of resources, libraries, frameworks, and tools to support Java development.
#
# In terms of use cases, Java is commonly used in various domains such as web development, mobile development (Android apps), enterprise applications, scientific computing, and more. Its significance lies in its stability, performance, security features, and the vast ecosystem of tools and libraries available to developers. Java's cross-platform compatibility and scalability make it a preferred choice for many organizations looking to build robust and reliable software solutions.
# AIMessageChunk(content='Content="In the realm of coding, a language divine,\nJava shines bright with a radiant design.\nElegant and robust, it stands the test of time,\nA versatile tool, a programmer\'s prime.\n\nWith its write once, run anywhere grace,\nJava dances through platforms with effortless pace.\nObject-oriented, its structure sublime,\nEncapsulating data in a seamless rhyme.\n\nFrom desktops to servers, it spreads its wings,\nHandling tasks big and small, the joy it brings.\nThreads and exceptions, it handles with care,\nJava, a language beyond compare.\n\nIn the vast world of tech, a guiding light,\nJava leads the way with power and might.\nA language of order, precision, and grace,\nForever beloved in the coding space.\n\nSo raise a toast to Java, noble and true,\nA language so timeless, a dream come true.\nIn the hands of programmers, its magic unfurls,\nJava, the language that rules the coding world."\n\nJava is a high-level, object-oriented programming language known for its portability, performance, and reliability. Developed by Sun Microsystems (now owned by Oracle Corporation), Java has become one of the most popular languages in the software development industry. Let\'s break down the key aspects of Java mentioned in the content:\n\n1. **Versatile and Robust:** Java is known for its versatility and robustness. It can be used for a wide range of applications, from desktop software to web applications, mobile apps, and enterprise systems.\n\n2. **Write Once, Run Anywhere (WORA):** Java\'s WORA principle allows developers to write code once and run it on any platform that supports Java without the need for recompilation. This makes Java highly portable and platform-independent.\n\n3. **Object-Oriented:** Java is a fully object-oriented language, which means it revolves around the concept of objects and classes. This paradigm promotes code reusability, modularity, and a clear structure.\n\n4. **Exception Handling:** Java provides robust mechanisms for handling exceptions, which are runtime errors that can occur during program execution. By using try-catch blocks, developers can gracefully handle exceptions and prevent program crashes.\n\n5. **Multithreading Support:** Java offers built-in support for multithreading, allowing developers to create programs that can execute multiple tasks concurrently. This feature is essential for developing responsive and efficient applications.\n\n6. **Scalability:** Java is well-suited for building scalable applications, from small utilities to large-scale enterprise systems. Its performance and scalability make it a popular choice for mission-critical applications.\n\n7. **Community Support:** Java has a large and active community of developers, which provides a wealth of resources, libraries, frameworks, and tools to support Java development.\n\nIn terms of use cases, Java is commonly used in various domains such as web development, mobile development (Android apps), enterprise applications, scientific computing, and more. Its significance lies in its stability, performance, security features, and the vast ecosystem of tools and libraries available to developers. Java\'s cross-platform compatibility and scalability make it a preferred choice for many organizations looking to build robust and reliable software solutions.')
